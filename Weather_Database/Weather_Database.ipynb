# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#import citipy 6.1.5
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['kerteh', 'mataura', 'amderma', 'batagay-alyta', 'muros', 'yar-sale', 'osijek', 'lebu', 'taltal', 'kawalu'] Generate 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f5b26a65a73570e25724bcfdba94c13a

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i != 0):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date, 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          'Weather Description':city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kerteh
# City not found. Skipping...
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | batagay-alyta
# Processing Record 5 of Set 1 | muros
# Processing Record 6 of Set 1 | yar-sale
# Processing Record 7 of Set 1 | osijek
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | taltal
# Processing Record 10 of Set 1 | kawalu
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | srednekolymsk
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | warmbad
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | normandin
# Processing Record 19 of Set 1 | victor harbor
# Processing Record 20 of Set 1 | dhule
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | pisco
# Processing Record 23 of Set 1 | nichinan
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | orocue
# Processing Record 26 of Set 1 | dunedin
# Processing Record 27 of Set 1 | ahuimanu
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | acapulco
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | evensk
# Processing Record 34 of Set 1 | san rafael
# Processing Record 35 of Set 1 | ormara
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | dukat
# Processing Record 38 of Set 1 | berlevag
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | kampot
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | yilan
# Processing Record 47 of Set 1 | dharchula
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | avera
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 2 | gat
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | chimore
# Processing Record 5 of Set 2 | axim
# Processing Record 6 of Set 2 | ancud
# Processing Record 7 of Set 2 | jalu
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | roald
# Processing Record 11 of Set 2 | ratnagiri
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | rio gallegos
# Processing Record 14 of Set 2 | cabo san lucas
# Processing Record 15 of Set 2 | sao joao da barra
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | hungund
# Processing Record 19 of Set 2 | el tigre
# Processing Record 20 of Set 2 | san policarpo
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | ambon
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | prince rupert
# Processing Record 27 of Set 2 | kupang
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | khorramshahr
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | zhigansk
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | sena madureira
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 2 | sibu
# Processing Record 38 of Set 2 | novobureyskiy
# Processing Record 39 of Set 2 | altay
# Processing Record 40 of Set 2 | saint george
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | poum
# Processing Record 43 of Set 2 | masyaf
# Processing Record 44 of Set 2 | carballo
# Processing Record 45 of Set 2 | takoradi
# Processing Record 46 of Set 2 | palmas bellas
# Processing Record 47 of Set 2 | bac lieu
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | abu dhabi
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | yefira
# City not found. Skipping...
# Processing Record 4 of Set 3 | clyde river
# Processing Record 5 of Set 3 | port hawkesbury
# Processing Record 6 of Set 3 | dalbandin
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | dicabisagan
# Processing Record 9 of Set 3 | navapur
# City not found. Skipping...
# Processing Record 10 of Set 3 | marawi
# Processing Record 11 of Set 3 | aketi
# Processing Record 12 of Set 3 | isangel
# Processing Record 13 of Set 3 | alice springs
# Processing Record 14 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | esqueda
# Processing Record 18 of Set 3 | saldanha
# Processing Record 19 of Set 3 | zheleznodorozhnyy
# Processing Record 20 of Set 3 | santa cruz del sur
# Processing Record 21 of Set 3 | pierre
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 3 | deblin
# Processing Record 25 of Set 3 | busselton
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | tucuman
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | lorengau
# Processing Record 30 of Set 3 | chuy
# Processing Record 31 of Set 3 | carutapera
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | manyana
# Processing Record 34 of Set 3 | brae
# Processing Record 35 of Set 3 | fairbanks
# Processing Record 36 of Set 3 | walvis bay
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 3 | charters towers
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | waingapu
# Processing Record 42 of Set 3 | brandon
# Processing Record 43 of Set 3 | qaqortoq
# Processing Record 44 of Set 3 | opuwo
# Processing Record 45 of Set 3 | kihei
# Processing Record 46 of Set 3 | mahebourg
# Processing Record 47 of Set 3 | ulaanbaatar
# Processing Record 48 of Set 3 | mount isa
# Processing Record 49 of Set 3 | hilo
# Processing Record 50 of Set 3 | east london
# Processing Record 1 of Set 4 | winslow
# Processing Record 2 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 4 | mandalgovi
# Processing Record 4 of Set 4 | namatanai
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | khasan
# Processing Record 7 of Set 4 | pimenteiras
# Processing Record 8 of Set 4 | vila franca do campo
# Processing Record 9 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 4 | moussoro
# Processing Record 11 of Set 4 | honningsvag
# Processing Record 12 of Set 4 | mount gambier
# Processing Record 13 of Set 4 | antalaha
# Processing Record 14 of Set 4 | quatre cocos
# Processing Record 15 of Set 4 | redmond
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | sao filipe
# Processing Record 18 of Set 4 | ballina
# Processing Record 19 of Set 4 | talaya
# Processing Record 20 of Set 4 | bubaque
# Processing Record 21 of Set 4 | fort-shevchenko
# Processing Record 22 of Set 4 | awash
# Processing Record 23 of Set 4 | jutai
# Processing Record 24 of Set 4 | oranjemund
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | korla
# Processing Record 27 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 4 | aklavik
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | bundoran
# Processing Record 31 of Set 4 | okhotsk
# Processing Record 32 of Set 4 | nekhayevskiy
# Processing Record 33 of Set 4 | kanker
# Processing Record 34 of Set 4 | castro
# Processing Record 35 of Set 4 | georgetown
# Processing Record 36 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 4 | coquimbo
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | lucapa
# Processing Record 40 of Set 4 | penzance
# Processing Record 41 of Set 4 | santa cruz
# Processing Record 42 of Set 4 | iqaluit
# Processing Record 43 of Set 4 | bara
# Processing Record 44 of Set 4 | yerbogachen
# Processing Record 45 of Set 4 | menongue
# Processing Record 46 of Set 4 | mount darwin
# Processing Record 47 of Set 4 | kodiak
# Processing Record 48 of Set 4 | nome
# Processing Record 49 of Set 4 | arkhara
# Processing Record 50 of Set 4 | ocos
# Processing Record 1 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | lavrentiya
# Processing Record 4 of Set 5 | suluq
# Processing Record 5 of Set 5 | tyrma
# Processing Record 6 of Set 5 | orumiyeh
# Processing Record 7 of Set 5 | koryazhma
# Processing Record 8 of Set 5 | sioux lookout
# Processing Record 9 of Set 5 | laguna
# Processing Record 10 of Set 5 | zlynka
# Processing Record 11 of Set 5 | salalah
# Processing Record 12 of Set 5 | gobabis
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | kavieng
# Processing Record 16 of Set 5 | tarime
# Processing Record 17 of Set 5 | puerto ayora
# Processing Record 18 of Set 5 | riyadh
# Processing Record 19 of Set 5 | methoni
# Processing Record 20 of Set 5 | paragominas
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | biak
# Processing Record 23 of Set 5 | kokopo
# Processing Record 24 of Set 5 | krasnoselkup
# Processing Record 25 of Set 5 | jiuquan
# Processing Record 26 of Set 5 | torbay
# Processing Record 27 of Set 5 | port macquarie
# Processing Record 28 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 5 | banjar
# Processing Record 30 of Set 5 | los llanos de aridane
# Processing Record 31 of Set 5 | peniche
# Processing Record 32 of Set 5 | vikulovo
# Processing Record 33 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 5 | panvel
# Processing Record 35 of Set 5 | el campo
# Processing Record 36 of Set 5 | raul soares
# Processing Record 37 of Set 5 | seymchan
# Processing Record 38 of Set 5 | tezu
# Processing Record 39 of Set 5 | vanimo
# Processing Record 40 of Set 5 | lushunkou
# City not found. Skipping...
# Processing Record 41 of Set 5 | longyearbyen
# Processing Record 42 of Set 5 | bambous virieux
# Processing Record 43 of Set 5 | monrovia
# Processing Record 44 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 5 | mar del plata
# Processing Record 47 of Set 5 | innisfail
# Processing Record 48 of Set 5 | portland
# Processing Record 49 of Set 5 | tabou
# Processing Record 50 of Set 5 | ponnani
# Processing Record 1 of Set 6 | kizukuri
# Processing Record 2 of Set 6 | rock sound
# Processing Record 3 of Set 6 | gornopravdinsk
# Processing Record 4 of Set 6 | morondava
# Processing Record 5 of Set 6 | valparaiso
# Processing Record 6 of Set 6 | rosetta
# Processing Record 7 of Set 6 | nenjiang
# Processing Record 8 of Set 6 | jamestown
# Processing Record 9 of Set 6 | bitam
# Processing Record 10 of Set 6 | ghanzi
# Processing Record 11 of Set 6 | sisimiut
# Processing Record 12 of Set 6 | raybag
# Processing Record 13 of Set 6 | taylor
# Processing Record 14 of Set 6 | kungurtug
# Processing Record 15 of Set 6 | victoria
# Processing Record 16 of Set 6 | venice
# Processing Record 17 of Set 6 | santa fe
# Processing Record 18 of Set 6 | hanmer springs
# Processing Record 19 of Set 6 | russkiy kameshkir
# Processing Record 20 of Set 6 | guerrero negro
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | sunland park
# Processing Record 23 of Set 6 | canto do buriti
# Processing Record 24 of Set 6 | tommot
# Processing Record 25 of Set 6 | hualmay
# Processing Record 26 of Set 6 | kavaratti
# Processing Record 27 of Set 6 | erenhot
# Processing Record 28 of Set 6 | khandyga
# Processing Record 29 of Set 6 | hay river
# Processing Record 30 of Set 6 | butajira
# Processing Record 31 of Set 6 | san cristobal
# Processing Record 32 of Set 6 | araouane
# Processing Record 33 of Set 6 | chirongui
# Processing Record 34 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 6 | labuhan
# Processing Record 36 of Set 6 | sorland
# Processing Record 37 of Set 6 | humboldt
# Processing Record 38 of Set 6 | sao jose da coroa grande
# Processing Record 39 of Set 6 | ilulissat
# Processing Record 40 of Set 6 | egvekinot
# Processing Record 41 of Set 6 | astoria
# Processing Record 42 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 6 | mustasaari
# Processing Record 44 of Set 6 | coahuayana
# Processing Record 45 of Set 6 | barrow
# Processing Record 46 of Set 6 | kharovsk
# Processing Record 47 of Set 6 | kwinana
# Processing Record 48 of Set 6 | qunduz
# Processing Record 49 of Set 6 | krosno odrzanskie
# Processing Record 50 of Set 6 | taboga
# Processing Record 1 of Set 7 | kollumerland
# City not found. Skipping...
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | sao caetano de odivelas
# Processing Record 4 of Set 7 | rawson
# Processing Record 5 of Set 7 | ponta delgada
# Processing Record 6 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 7 | pangnirtung
# Processing Record 8 of Set 7 | kyren
# Processing Record 9 of Set 7 | wukari
# Processing Record 10 of Set 7 | grand gaube
# Processing Record 11 of Set 7 | comodoro rivadavia
# Processing Record 12 of Set 7 | warragul
# Processing Record 13 of Set 7 | nueva concepcion
# Processing Record 14 of Set 7 | itarema
# Processing Record 15 of Set 7 | bonavista
# Processing Record 16 of Set 7 | barberton
# Processing Record 17 of Set 7 | sulina
# Processing Record 18 of Set 7 | te anau
# Processing Record 19 of Set 7 | svetlyy
# Processing Record 20 of Set 7 | dabeiba
# Processing Record 21 of Set 7 | bardiyah
# Processing Record 22 of Set 7 | ulaangom
# Processing Record 23 of Set 7 | oxford
# Processing Record 24 of Set 7 | olafsvik
# Processing Record 25 of Set 7 | conde
# Processing Record 26 of Set 7 | wanning
# Processing Record 27 of Set 7 | port augusta
# Processing Record 28 of Set 7 | beringovskiy
# Processing Record 29 of Set 7 | domoni
# Processing Record 30 of Set 7 | ryotsu
# Processing Record 31 of Set 7 | aksarka
# Processing Record 32 of Set 7 | puerto escondido
# Processing Record 33 of Set 7 | zelenchukskaya
# Processing Record 34 of Set 7 | chokurdakh
# Processing Record 35 of Set 7 | hambantota
# Processing Record 36 of Set 7 | niceville
# Processing Record 37 of Set 7 | meulaboh
# Processing Record 38 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 39 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 40 of Set 7 | baherden
# Processing Record 41 of Set 7 | luganville
# Processing Record 42 of Set 7 | oparino
# Processing Record 43 of Set 7 | agadir
# Processing Record 44 of Set 7 | vardo
# Processing Record 45 of Set 7 | itaueira
# Processing Record 46 of Set 7 | nizwa
# Processing Record 47 of Set 7 | hirtshals
# Processing Record 48 of Set 7 | sarlat-la-caneda
# Processing Record 49 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 7 | ewa beach
# Processing Record 1 of Set 8 | faya
# Processing Record 2 of Set 8 | san jeronimo
# Processing Record 3 of Set 8 | rocha
# Processing Record 4 of Set 8 | port-gentil
# Processing Record 5 of Set 8 | bilibino
# Processing Record 6 of Set 8 | at-bashi
# Processing Record 7 of Set 8 | rapid city
# Processing Record 8 of Set 8 | kahului
# Processing Record 9 of Set 8 | finnsnes
# Processing Record 10 of Set 8 | katobu
# Processing Record 11 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 8 | kruisfontein
# Processing Record 13 of Set 8 | dudinka
# Processing Record 14 of Set 8 | kieta
# Processing Record 15 of Set 8 | padre bernardo
# Processing Record 16 of Set 8 | buchanan
# Processing Record 17 of Set 8 | vestmanna
# Processing Record 18 of Set 8 | presidente medici
# Processing Record 19 of Set 8 | kamwenge
# Processing Record 20 of Set 8 | cap malheureux
# Processing Record 21 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 22 of Set 8 | port hardy
# Processing Record 23 of Set 8 | inirida
# Processing Record 24 of Set 8 | westport
# Processing Record 25 of Set 8 | hita
# Processing Record 26 of Set 8 | awjilah
# Processing Record 27 of Set 8 | boyolangu
# Processing Record 28 of Set 8 | eunice
# Processing Record 29 of Set 8 | chaa-khol
# City not found. Skipping...
# Processing Record 30 of Set 8 | hamilton
# Processing Record 31 of Set 8 | gizo
# Processing Record 32 of Set 8 | miyako
# Processing Record 33 of Set 8 | saldana
# Processing Record 34 of Set 8 | teknaf
# Processing Record 35 of Set 8 | keshod
# Processing Record 36 of Set 8 | xining
# Processing Record 37 of Set 8 | praia da vitoria
# Processing Record 38 of Set 8 | coihaique
# Processing Record 39 of Set 8 | gelemso
# Processing Record 40 of Set 8 | ornes
# Processing Record 41 of Set 8 | kampene
# Processing Record 42 of Set 8 | henties bay
# Processing Record 43 of Set 8 | absam
# Processing Record 44 of Set 8 | eldorado
# Processing Record 45 of Set 8 | emerald
# Processing Record 46 of Set 8 | baker city
# Processing Record 47 of Set 8 | belmonte
# Processing Record 48 of Set 8 | broome
# Processing Record 49 of Set 8 | palmas de monte alto
# Processing Record 50 of Set 8 | the pas
# Processing Record 1 of Set 9 | leshukonskoye
# Processing Record 2 of Set 9 | oktyabrskoye
# Processing Record 3 of Set 9 | hobyo
# Processing Record 4 of Set 9 | katherine
# Processing Record 5 of Set 9 | satu mare
# Processing Record 6 of Set 9 | neiafu
# Processing Record 7 of Set 9 | mabilbila
# City not found. Skipping...
# Processing Record 8 of Set 9 | tateyama
# Processing Record 9 of Set 9 | kununurra
# Processing Record 10 of Set 9 | sechura
# Processing Record 11 of Set 9 | leh
# Processing Record 12 of Set 9 | sanand
# Processing Record 13 of Set 9 | anadyr
# Processing Record 14 of Set 9 | dingle
# Processing Record 15 of Set 9 | progreso
# Processing Record 16 of Set 9 | chumikan
# Processing Record 17 of Set 9 | clonakilty
# Processing Record 18 of Set 9 | santa marta
# Processing Record 19 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 9 | kloulklubed
# Processing Record 21 of Set 9 | norman wells
# Processing Record 22 of Set 9 | nanortalik
# Processing Record 23 of Set 9 | chapais
# Processing Record 24 of Set 9 | mahibadhoo
# Processing Record 25 of Set 9 | strezhevoy
# Processing Record 26 of Set 9 | lompoc
# Processing Record 27 of Set 9 | kaiyuan
# Processing Record 28 of Set 9 | makurdi
# Processing Record 29 of Set 9 | rylsk
# Processing Record 30 of Set 9 | pontianak
# Processing Record 31 of Set 9 | beisfjord
# Processing Record 32 of Set 9 | aloleng
# Processing Record 33 of Set 9 | anito
# Processing Record 34 of Set 9 | kazachinskoye
# Processing Record 35 of Set 9 | linjiang
# Processing Record 36 of Set 9 | aktash
# Processing Record 37 of Set 9 | palembang
# Processing Record 38 of Set 9 | bayji
# Processing Record 39 of Set 9 | majene
# Processing Record 40 of Set 9 | calbuco
# Processing Record 41 of Set 9 | baksheyevo
# Processing Record 42 of Set 9 | hovd
# Processing Record 43 of Set 9 | raudeberg
# Processing Record 44 of Set 9 | naze
# Processing Record 45 of Set 9 | caala
# Processing Record 46 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 9 | telhara
# Processing Record 48 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 9 | jabinyanah
# Processing Record 50 of Set 9 | high rock
# Processing Record 1 of Set 10 | parchim
# Processing Record 2 of Set 10 | akhtubinsk
# Processing Record 3 of Set 10 | blagoyevo
# Processing Record 4 of Set 10 | iralaya
# Processing Record 5 of Set 10 | marystown
# Processing Record 6 of Set 10 | sim
# Processing Record 7 of Set 10 | kodinsk
# Processing Record 8 of Set 10 | eisiskes
# Processing Record 9 of Set 10 | port blair
# Processing Record 10 of Set 10 | ongandjera
# Processing Record 11 of Set 10 | muisne
# Processing Record 12 of Set 10 | zile
# Processing Record 13 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 10 | kindu
# Processing Record 15 of Set 10 | lasa
# Processing Record 16 of Set 10 | port lincoln
# Processing Record 17 of Set 10 | huntington
# Processing Record 18 of Set 10 | owo
# Processing Record 19 of Set 10 | jaciara
# Processing Record 20 of Set 10 | surt
# Processing Record 21 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 10 | tromso
# Processing Record 23 of Set 10 | montbrison
# Processing Record 24 of Set 10 | komsomolskiy
# Processing Record 25 of Set 10 | gonbad-e qabus
# Processing Record 26 of Set 10 | goderich
# Processing Record 27 of Set 10 | staroye drozhzhanoye
# Processing Record 28 of Set 10 | oum hadjer
# Processing Record 29 of Set 10 | luderitz
# Processing Record 30 of Set 10 | mugur-aksy
# Processing Record 31 of Set 10 | bintulu
# Processing Record 32 of Set 10 | ust-nera
# Processing Record 33 of Set 10 | flinders
# Processing Record 34 of Set 10 | pontes e lacerda
# Processing Record 35 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 10 | viseu
# Processing Record 37 of Set 10 | adamas
# Processing Record 38 of Set 10 | baoning
# Processing Record 39 of Set 10 | pachalum
# Processing Record 40 of Set 10 | auki
# Processing Record 41 of Set 10 | kirsanov
# Processing Record 42 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 10 | sapele
# Processing Record 44 of Set 10 | uyskoye
# Processing Record 45 of Set 10 | skjervoy
# Processing Record 46 of Set 10 | dawlatabad
# Processing Record 47 of Set 10 | suifenhe
# Processing Record 48 of Set 10 | shouguang
# Processing Record 49 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 10 | qujing
# Processing Record 1 of Set 11 | launceston
# Processing Record 2 of Set 11 | verkhnevilyuysk
# Processing Record 3 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 4 of Set 11 | cap-aux-meules
# Processing Record 5 of Set 11 | korcula
# Processing Record 6 of Set 11 | foz
# Processing Record 7 of Set 11 | lagoa
# Processing Record 8 of Set 11 | faanui
# Processing Record 9 of Set 11 | yarada
# Processing Record 10 of Set 11 | bell ville
# Processing Record 11 of Set 11 | sherman
# Processing Record 12 of Set 11 | husavik
# Processing Record 13 of Set 11 | kasane
# Processing Record 14 of Set 11 | grindavik
# Processing Record 15 of Set 11 | katakwi
# Processing Record 16 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 11 | taoudenni
# Processing Record 18 of Set 11 | banamba
# Processing Record 19 of Set 11 | college
# Processing Record 20 of Set 11 | tyukalinsk
# Processing Record 21 of Set 11 | porto novo
# Processing Record 22 of Set 11 | yashkul
# Processing Record 23 of Set 11 | jumilla
# Processing Record 24 of Set 11 | saint-paul
# Processing Record 25 of Set 11 | ondangwa
# Processing Record 26 of Set 11 | saint-pierre
# Processing Record 27 of Set 11 | troitskoye
# Processing Record 28 of Set 11 | nyrany
# Processing Record 29 of Set 11 | mocuba
# Processing Record 30 of Set 11 | kupino
# Processing Record 31 of Set 11 | capinzal
# Processing Record 32 of Set 11 | pinega
# Processing Record 33 of Set 11 | santa maria
# Processing Record 34 of Set 11 | road town
# Processing Record 35 of Set 11 | ailigandi
# Processing Record 36 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 11 | barra
# Processing Record 38 of Set 11 | cavalcante
# Processing Record 39 of Set 11 | tacuarembo
# Processing Record 40 of Set 11 | nizhniy odes
# Processing Record 41 of Set 11 | macapa
# Processing Record 42 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 11 | jining
# Processing Record 44 of Set 11 | mareeba
# Processing Record 45 of Set 11 | waipawa
# Processing Record 46 of Set 11 | larsnes
# Processing Record 47 of Set 11 | bahia honda
# Processing Record 48 of Set 11 | aswan
# Processing Record 49 of Set 11 | caborca
# Processing Record 50 of Set 11 | sohagpur
# Processing Record 1 of Set 12 | fuling
# Processing Record 2 of Set 12 | lapithos
# Processing Record 3 of Set 12 | ostrovnoy
# Processing Record 4 of Set 12 | liverpool
# Processing Record 5 of Set 12 | necochea
# Processing Record 6 of Set 12 | candolim
# Processing Record 7 of Set 12 | wanaka
# Processing Record 8 of Set 12 | havre-saint-pierre
# Processing Record 9 of Set 12 | carbondale
# Processing Record 10 of Set 12 | general roca
# Processing Record 11 of Set 12 | piritiba
# Processing Record 12 of Set 12 | cockburn town
# Processing Record 13 of Set 12 | buta
# Processing Record 14 of Set 12 | rurrenabaque
# Processing Record 15 of Set 12 | muzhi
# Processing Record 16 of Set 12 | kirkcudbright
# Processing Record 17 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 12 | primo tapia
# Processing Record 19 of Set 12 | mezen
# Processing Record 20 of Set 12 | birao
# Processing Record 21 of Set 12 | leningradskiy
# Processing Record 22 of Set 12 | half moon bay
# Processing Record 23 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 12 | sungaipenuh
# Processing Record 25 of Set 12 | aripuana
# Processing Record 26 of Set 12 | champerico
# Processing Record 27 of Set 12 | araguacu
# Processing Record 28 of Set 12 | bahawalnagar
# Processing Record 29 of Set 12 | rehoboth
# Processing Record 30 of Set 12 | kiruna
# Processing Record 31 of Set 12 | whitehorse
# Processing Record 32 of Set 12 | mehamn
# Processing Record 33 of Set 12 | chalus
# Processing Record 34 of Set 12 | kudahuvadhoo
# Processing Record 35 of Set 12 | el alto
# Processing Record 36 of Set 12 | moron
# Processing Record 37 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 38 of Set 12 | bhinmal
# Processing Record 39 of Set 12 | bajil
# Processing Record 40 of Set 12 | prince george
# Processing Record 41 of Set 12 | neryungri
# Processing Record 42 of Set 12 | bhimunipatnam
# Processing Record 43 of Set 12 | sainte-thecle
# Processing Record 44 of Set 12 | sulzbach-rosenberg
# Processing Record 45 of Set 12 | sur
# Processing Record 46 of Set 12 | indianola
# Processing Record 47 of Set 12 | koungou
# Processing Record 48 of Set 12 | manta
# Processing Record 49 of Set 12 | caraguatatuba
# Processing Record 50 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 1 of Set 13 | ugra
# Processing Record 2 of Set 13 | katsuura
# Processing Record 3 of Set 13 | killini
# City not found. Skipping...
# Processing Record 4 of Set 13 | bilma
# Processing Record 5 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 13 | toamasina
# Processing Record 8 of Set 13 | cidreira
# Processing Record 9 of Set 13 | sandwick
# Processing Record 10 of Set 13 | margate
# Processing Record 11 of Set 13 | constitucion
# Processing Record 12 of Set 13 | nokia
# Processing Record 13 of Set 13 | katangli
# Processing Record 14 of Set 13 | invermere
# Processing Record 15 of Set 13 | cayenne
# Processing Record 16 of Set 13 | chengde
# Processing Record 17 of Set 13 | sabha
# Processing Record 18 of Set 13 | gidam
# Processing Record 19 of Set 13 | iquique
# Processing Record 20 of Set 13 | boende
# Processing Record 21 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 22 of Set 13 | gunjur
# Processing Record 23 of Set 13 | balikpapan
# Processing Record 24 of Set 13 | harper
# Processing Record 25 of Set 13 | sydney mines
# Processing Record 26 of Set 13 | vredendal
# Processing Record 27 of Set 13 | tacoronte
# Processing Record 28 of Set 13 | buala
# Processing Record 29 of Set 13 | sitka
# Processing Record 30 of Set 13 | eyl
# Processing Record 31 of Set 13 | evanston
# Processing Record 32 of Set 13 | bayan
# Processing Record 33 of Set 13 | nema
# Processing Record 34 of Set 13 | malangali
# Processing Record 35 of Set 13 | ahipara
# Processing Record 36 of Set 13 | saint-georges
# Processing Record 37 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 13 | stornoway
# Processing Record 39 of Set 13 | spearfish
# Processing Record 40 of Set 13 | semey
# Processing Record 41 of Set 13 | narsaq
# Processing Record 42 of Set 13 | shreveport
# Processing Record 43 of Set 13 | linxia
# Processing Record 44 of Set 13 | atbasar
# Processing Record 45 of Set 13 | alofi
# Processing Record 46 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 13 | kinsale
# Processing Record 48 of Set 13 | kutum
# Processing Record 49 of Set 13 | great yarmouth
# Processing Record 50 of Set 13 | rio tercero
# Processing Record 1 of Set 14 | kargat
# Processing Record 2 of Set 14 | coihueco
# Processing Record 3 of Set 14 | la asuncion
# Processing Record 4 of Set 14 | anloga
# Processing Record 5 of Set 14 | broken hill
# Processing Record 6 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 14 | rio grande
# Processing Record 8 of Set 14 | genhe
# Processing Record 9 of Set 14 | coruripe
# Processing Record 10 of Set 14 | nadym
# Processing Record 11 of Set 14 | plettenberg bay
# Processing Record 12 of Set 14 | kimbe
# Processing Record 13 of Set 14 | santa cruz cabralia
# Processing Record 14 of Set 14 | aykhal
# Processing Record 15 of Set 14 | atambua
# Processing Record 16 of Set 14 | tongliao
# Processing Record 17 of Set 14 | stephenville
# Processing Record 18 of Set 14 | sept-iles
# Processing Record 19 of Set 14 | mecca
# Processing Record 20 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 14 | montevideo
# Processing Record 22 of Set 14 | uige
# Processing Record 23 of Set 14 | suicheng
# Processing Record 24 of Set 14 | perth
# Processing Record 25 of Set 14 | matsanga
# City not found. Skipping...
# Processing Record 26 of Set 14 | palauig
# Processing Record 27 of Set 14 | la trinite
# Processing Record 28 of Set 14 | yantarnyy
# Processing Record 29 of Set 14 | kapoeta
# Processing Record 30 of Set 14 | hofn
# Processing Record 31 of Set 14 | tucuma
# Processing Record 32 of Set 14 | sidi qasim
# City not found. Skipping...
# Processing Record 33 of Set 14 | nuevo progreso
# Processing Record 34 of Set 14 | bathsheba
# Processing Record 35 of Set 14 | filadelfia
# Processing Record 36 of Set 14 | saint anthony
# Processing Record 37 of Set 14 | vangaindrano
# Processing Record 38 of Set 14 | odweyne
# Processing Record 39 of Set 14 | hegang
# Processing Record 40 of Set 14 | san quintin
# Processing Record 41 of Set 14 | touros
# Processing Record 42 of Set 14 | ekhabi
# Processing Record 43 of Set 14 | surdila-gaiseanca
# Processing Record 44 of Set 14 | belyy yar
# Processing Record 45 of Set 14 | mayo
# Processing Record 46 of Set 14 | halifax
# Processing Record 47 of Set 14 | dabat
# Processing Record 48 of Set 14 | omsukchan
# Processing Record 49 of Set 14 | clarence town
# Processing Record 50 of Set 14 | les cayes
# Processing Record 1 of Set 15 | novelda
# Processing Record 2 of Set 15 | dong hoi
# Processing Record 3 of Set 15 | lubango
# Processing Record 4 of Set 15 | tutayev
# Processing Record 5 of Set 15 | inhambane
# Processing Record 6 of Set 15 | pemba
# Processing Record 7 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 15 | arkhangelsk
# Processing Record 9 of Set 15 | durban
# Processing Record 10 of Set 15 | baoding
# Processing Record 11 of Set 15 | coffs harbour
# Processing Record 12 of Set 15 | valdivia
# Processing Record 13 of Set 15 | bangassou
# Processing Record 14 of Set 15 | eureka
# Processing Record 15 of Set 15 | oranjestad
# Processing Record 16 of Set 15 | gamba
# Processing Record 17 of Set 15 | atasu
# Processing Record 18 of Set 15 | yarmouth
# Processing Record 19 of Set 15 | marsh harbour
# Processing Record 20 of Set 15 | san francisco
# Processing Record 21 of Set 15 | manoharpur
# Processing Record 22 of Set 15 | sabang
# Processing Record 23 of Set 15 | diamantino
# Processing Record 24 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 15 | thinadhoo
# Processing Record 26 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 15 | marzuq
# Processing Record 28 of Set 15 | baykit
# Processing Record 29 of Set 15 | raahe
# Processing Record 30 of Set 15 | gravelbourg
# Processing Record 31 of Set 15 | usukhchay
# Processing Record 32 of Set 15 | olinda
# Processing Record 33 of Set 15 | mandan
# Processing Record 34 of Set 15 | altamira
# Processing Record 35 of Set 15 | rumuruti
# Processing Record 36 of Set 15 | esik
# Processing Record 37 of Set 15 | maragogi
# Processing Record 38 of Set 15 | kirov
# Processing Record 39 of Set 15 | mesyagutovo
# Processing Record 40 of Set 15 | praia
# Processing Record 41 of Set 15 | haines junction
# Processing Record 42 of Set 15 | palmer
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0        Mataura      NZ  2021-08-10 03:19:49 -46.1927  168.8643     47.48
# 1  Batagay-Alyta      RU  2021-08-10 03:23:49  67.8006  130.4114     76.64
# 2          Muros      ES  2021-08-10 03:23:50  42.7762   -9.0603     60.24
# 3       Yar-Sale      RU  2021-08-10 03:20:19  66.8333   70.8333     56.03
# 4         Osijek      HR  2021-08-10 03:23:50  45.5511   18.6939     71.42
# 5           Lebu      CL  2021-08-10 03:23:50 -37.6167  -73.6500     46.71
# 6         Taltal      CL  2021-08-10 03:23:51 -25.4000  -70.4833     58.28
# 7         Kawalu      ID  2021-08-10 03:23:51  -7.3817  108.2082     78.15
# 8        Qaanaaq      GL  2021-08-10 03:23:52  77.4840  -69.3632     38.95
# 9  Srednekolymsk      RU  2021-08-10 03:23:52  67.4500  153.6833     78.13
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        96         100        8.99          light rain
# 1        25          70        7.31       broken clouds
# 2        91           0        5.14           clear sky
# 3        71          21       13.51          few clouds
# 4        94           0        5.75           clear sky
# 5        87           1       17.56           clear sky
# 6        77          34        4.74    scattered clouds
# 7        81          96        4.12     overcast clouds
# 8        75          86        7.31     overcast clouds
# 9        30          59        9.33       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
challenge_city_data_df.to_csv(output_data_file, index_label="City_ID")
